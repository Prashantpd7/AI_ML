# %%
import numpy as np

# %%
data = [10,20,30,40,100,48]

# %%
print(np.mean(data))
# Out:
# 41.333333333333336

# %%
import statistics

# %%
print(np.var(data))
# Out:
# 842.2222222222222

# %%
print(np.var(data[0:4], ddof = 1))
# Out:
# 166.66666666666666

# %%
print(np.std(data))
# Out:
# 29.021065146238552
